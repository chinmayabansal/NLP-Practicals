# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import os
from os.path import basename

# %%
url="https://www.niituniversity.in/faculty"

# %%
reques = requests.get(url)

# %%
page = reques.content
soup = BeautifulSoup(page,'lxml')
file = ""
b= bytes(soup.get_text(),'utf-8')
with open("Faculty_page.html","wb") as f:
    f.write(b)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js">
# <!--<![endif]-->
# <head>
# <!-- Google Tag Manager -->
# <script>        (function (w, d, s, l, i) {
#             w[l] = w[l] || []; w[l].push({ 'gtm.start':
# new Date().getTime(), event: 'gtm.js'
#             }); var f = d.getElementsByTagName(s)[0],
# j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-5NW727B');</script>
# <!-- End Google Tag Manager -->
# <!--Start of Connecto Tracking script-->
# <script type="text/javascript">
#         !function () {
#             var t = window._connecto = window._connecto || [];
#             t.methods = ["track", "identify", "page"], t.factory = function (e) { return function () { var o = Array.prototype.slice.call(arguments); return o.unshift(e), t.push(o), t } };
#             for (var e = 0; e < t.methods.length; e++) { var o = t.methods[e]; t[o] = t.factory(o) } t.load = function (t) {
#                 window._connecto.writeKey = t;
#                 var e = document.createElement("script"); e.type = "text/javascript", e.async = !0;
#                 var o = "http:" === document.location.protocol ? "http://cdn" : "https://api"; e.src = o + ".connecto.io/javascripts/chrome_connecto.prod.min.js";
#                 var n = document.getElementsByTagName("script")[0]; n.parentNode.insertBefore(e, n)
#             }, t.load("KSE5xjEKHvNHd8Hk")
#         } ();
#     </script>
# <!--End of Connecto Script-->
# <!-- Schema.org script -->
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "EducationalOrganization",
#   "address": {
#     "@type": "PostalAddress",
#     "addressLocality": "Neemrana, District Alwar",
#     "addressRegion": "Rajasthan",
#     "postalCode": "301705",
#     "streetAddress": "NH 8, Delhi Jaipur Highway"
#   },
#   "alumni": [
#     {
#       "@type": "Person",
#       "name": "PARESH NAYYAR"
#     },
# 	{
#       "@type": "Person",
#       "name": "Ujwal Ratra"
#     },
# 	{
#       "@type": "Person",
#       "name": "Atif Inayat Khan"
#     },
#     {
#       "@type": "Person",
#       "name": "ROHAN BHATIA"
#     }
#   ],
#   "name": "NIIT University",
#   "aggregateRating": {
#     "@type": "AggregateRating",
#     "ratingValue": "4.2",
#     "bestRating": "5",
#     "worstRating": "1",
#     "ratingCount": "98"
#   },
#   "review": {
#     "@type": "Review",
#     "url": "https://www.niituniversity.in/",
#     "author": {
#       "@type": "Person",
#       "name": "Rishab Sharma",
#       "sameAs": "https://goo.gl/maps/M2JZ4UEZd322"
#     },
#     "datePublished": "2017-09-04T20:00",
#     "description": "One of those rare universities which are great at everything, the way of teaching, management, campus, food, faculty, course content, culture, fests, quality of students, etc. They focus on the learnings and skills relevant to the industry which makes the students knowledgeable and employable. TALF is one of my favorite initiatives here among many other activities where you get to learn about our culture and looking through lenses in order to understand situations and taking decisions. You will experience TEDx, Sunburn, and many other activities during your stay.",
#     "inLanguage": "en"
# }
# }
#
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "CollegeOrUniversity",
#   "name": "NIIT University",
#   "alternateName": "NU",
#   "url": "https://www.niituniversity.in/",
#   "logo": "https://www.niituniversity.in/img/niit-logo.png",
#   "sameAs": [
# 		"https://www.facebook.com/NIITUniv",
# 		"https://twitter.com/niituniversity",
# 		"https://www.youtube.com/user/niituniv"
#   ]
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org/",
#   "@type": "Review",
#   "itemReviewed": {
#     "@type": "EducationalOrganization",
#     "image": "https://www.niituniversity.in/img/niit-logo.png",
#     "name": "NIIT University"
#   },
#   "reviewRating": {
#     "@type": "Rating",
#     "ratingValue": "4.3"
#   },
#   "name": "A good seafood place.",
#   "author": {
#     "@type": "Person",
#     "name": "Anshima P Srivastav"
#   },
#   "reviewBody": "This is one of the best universities in the country. The curriculum design, industry linkages the co curricular activities, all make it one of the the best centres for learning",
#   "publisher": {
#     "@type": "Organization",
#     "name": "Facebook"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "EducationEvent",
#   "name": "Campuss Buzz",
#   "location": {
#     "@type": "Place",
#     "name": "NIIT University's Events Page",
#     "sameAs": "https://www.niituniversity.in/campus-buzz",
#     "address": "Neemrana, Rajasthan"
#   },
#   "startDate": "2017-10-01T19:30"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "B.Tech - Biotechnology",
#   "description": "B Tech Programme for Biotechnology at NIIT University of Engineering.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "B Tech - Computer Science Engineering (CSE)",
#   "description": "B Tech Programme for CSE at NIIT University of Engineering.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "B.Tech - Electronics and Communication Engineering",
#   "description": "B Tech Programme for ECE at NIIT University of Engineering.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "M Tech Geographic Information Systems (GIS)",
#   "description": "M Tech in Geographic Information Systems (GIS) Programme at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "M Tech - Educational Technology (ET)",
#   "description": "M Tech - Educational Technology (ET) Programme at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "MBA",
#   "description": "NU MBA Programme at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "B.Tech & M.S",
#   "description": "B Tech & M.S Dual Degree Programme  at NU & University of Missouri-Kansas City.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "B Tech-M.Tech",
#   "description": "B Tech-M Tech Integrated Dual Degree Programme at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "MBA (Business Analytics)",
#   "description": "MBA (Business Analytics) Programme with WNS at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "MBA (Finance & Banking)",
#   "description": "MBA (Finance & Banking) with ICICI Bank at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "M.Tech (Cyber Security)",
#   "description": "M Tech (Cyber Security) Programme with PwC at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "PGDBRM",
#   "description": "PGDBRM Programme with Federal Bank at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "PGD (Banking & Finance)",
#   "description": "PGD (Banking & Finance) Programme with United Bank of India at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "PGD (Banking & Finance)",
#   "description": "PGD (Banking & Finance) Programme with Bank of Maharashtra at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "PhD Biotechnology",
#   "description": "PhD Biotechnology Programme at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "PhD Computer Science",
#   "description": "PhD Computer Science Programme at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "PhD Geographic Information Systems",
#   "description": "PhD Geographic Information Systems Programme at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "PhD Mathematics & Basic Sciences",
#   "description": "PhD Mathematics & Basic Sciences Programme at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Course",
#   "name": "PhD Management Disciplines",
#   "description": "PhD Management Disciplines Programme at NIIT University.",
#   "provider": {
#     "@type": "Organization",
#     "name": "NIIT University",
#     "sameAs": "https://www.niituniversity.in/"
#   }
# }
#     </script>
# <!-- Schema.org script -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Faculty - NIIT University</title>
# <meta content="NIIT University endlessly modernizes the knowledge and abilities of the faculties in numerous organizations under its authority." name="description"/>
# <meta content="faculty, b tech courses, courses in mba, m tech university" name="keywords"/>
# <style>
#         .bannerSection {
#             position: relative;
#             float: left;
#             width: 100%;
#             background: url(/resourcecontent/faculty-main-banner-desk.jpg) no-repeat center;
#         }
#     </style>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="/img/favicon.ico" rel="shortcut icon"/>
# <link href="/css/normalize.css" rel="stylesheet"/>
# <link href="/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/css/slick-slider.css" rel="stylesheet"/>
# <link href="/css/flexslider.css" rel="stylesheet"/>
# <link href="/css/fancybox.css" rel="stylesheet"/>
# <!--<link rel="stylesheet" href="/css/ddmenu.css"/>-->
# <link href="https://code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/css/menu.css" rel="stylesheet"/>
# <link href="/css/main.css" rel="stylesheet"/>
# <link href="/css/responsive.css" rel="stylesheet"/>
# <link href="/css/style.css" rel="stylesheet"/>
# <link href="/css/media.css" rel="stylesheet"/>
# <link href="/css/goutham.font.css" rel="stylesheet"/>
# <!-- Connect manifest json linking -->
# <link href="/connecto_manifest.json" rel="manifest"/>
# <script type="text/javascript">
#         (function (doc) {
#
#             var addEvent = 'addEventListener',
# 	    type = 'gesturestart',
# 	    qsa = 'querySelectorAll',
# 	    scales = [1, 1],
# 	    meta = qsa in doc ? doc[qsa]('meta[name=viewport]') : [];
#
#             function fix() {
#                 meta.content = 'width=device-width,minimum-scale=' + scales[0] + ',maximum-scale=' + scales[1];
#                 doc.removeEventListener(type, fix, true);
#             }
#
#             if ((meta = meta[meta.length - 1]) && addEvent in doc) {
#                 fix();
#                 scales = [.25, 1.6];
#                 doc[addEvent](type, fix, true);
#             }
#             _connecto.push(['onload', function () { _connecto.initPushRegistration() } ]);
#
#         } (document));
#     </script>
# <link href="https://www.niituniversity.in/faculty" rel="canonical"/>
# <!--Start of Zopim Live Chat Script-->
# <script type="text/javascript">
# </script>
# <!--End of Zopim Live Chat Script-->
# <style>
#         @media only screen and(max-width : 479)
#         {
#             .jx_ui_Widget
#             {
#                 display: none !important;
#             }
#         }
#     </style>
# <script type="text/javascript">
#         var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
#         document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
#     </script>
# <script type="text/javascript">
#         try {
#             var pageTracker = _gat._getTracker("UA-7425699-2");
#             pageTracker._trackPageview();
#         } catch (err) { }</script>
# <script type="text/javascript">
# <!-- function to bind lead_id parameter from B.Tech page URL -->
# function newURL(url){
# 	if(!url.href.includes(window.location.search))
# 		url.href = url.href + window.location.search;
# }
#     </script>
# <!-- Hotjar Tracking Code for http://niit.com -->
# <script>
#         (function (h, o, t, j, a, r) {
#             h.hj = h.hj || function () { (h.hj.q = h.hj.q || []).push(arguments) };
#             h._hjSettings = { hjid: 259389, hjsv: 5 };
#             a = o.getElementsByTagName('head')[0];
#             r = o.createElement('script'); r.async = 1;
#             r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#             a.appendChild(r);
#         })(window, document, '//static.hotjar.com/c/hotjar-', '.js?sv=');
#     </script>
# <script>        window._izq = window._izq || []; window._izq.push(["init"]); </script>
# <script src="https://cdn.izooto.com/scripts/a8433310b8017e6ab2f41d3ab8eba903178c7170.js"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5NW727B" style="display: none; visibility: hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!--Start of Connecto Script
# <script type="text/javascript">
#     var _TConnecto = _TConnecto || {};
#     _TConnecto.licenseKey = 'A0MNSVOCGpzuc29g';
#
#     (function () {
#         var con = document.createElement('script'); con.type = 'text/javascript';
#         var host = (document.location.protocol === 'http:') ? 'http://cdn' : 'https://server';
#         con.src = host + '.connecto.io/javascripts/connect.prod.min.js';
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(con, s);
#     })();
# </script>
# <!--End of Connecto Script-->
# <div class="overlay">
# </div>
# <div class="width100Per">
# <header>
# <section class="section1">
# <div class="sec1">
# <div class="row ">
# <div class="col-md-3 col-xs-2 menuimage hide1 mobile_nav " id="menuimage">
# <div class="margintopm10">
# <img src="/Desktop_images/mob_nav.PNG"/><span class="menu showdesktop "><strong>MENU</strong></span>
# </div>
# <!-- <div class="borderlinesec1"></div> -->
# </div>
# <div class="col-md-3 col-xs-2 menuimage1 hide2 mobile_nav" style="display:none">
# <div>
# <img class="showdesktop" src="/Desktop_images/wrong1.PNG"/><img class="showmobile mobileshowimg1" src="/Desktop_images/mob_nav.PNG"/>
# </div>
# <div class="triangle"></div>
# </div>
# <div class="col-md-6 col-xs-5">
# <a href="/">
# <img class="img_logo" id="logo" src="/Desktop_images/Slice_0.png"/>
# <img class="img_logo1" src="/mobile_images/logo.png"/>
# </a>
# </div>
# <div class="col-md-3 col-xs-5 searchbtn fordesktop" id="search">
# <div id="custom-search-input">
# <form action="/search-result.aspx" id="Form1" method="get" onsubmit="return fnSearch(2);">
# <input class="mySearch" id="searchText" name="q" placeholder="Search" type="text"/>
# </form>
# </div>
# </div>
# <div class="col-xs-4 searchbtn phone search-form" id="search">
# <form action="/search-result.aspx" id="frmSearch" method="get" onsubmit="return fnSearchPhone(2);">
# <input class="mySearch" id="searchTextPhone" name="q" placeholder="Search" type="text"/> <a class="srch-btn" href="javascript:;"><i class="fa fa-search" onclick="fnSearchPhone(1);"></i>
# </a>
# </form>
# </div>
# </div>
# </div>
# <div class="mynavbar hidden">
# <div class="container">
# <div class="row">
# <div class="fordesktop">
# <div class="col-sm-4">
# <div class="">
# <div class="menu_main_heading"><a class="color83181a" href="/about-nu">About NU </a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/vision-and-mission">Vision &amp; Mission </a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/core-principles">Core Principles </a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/leadership">Leadership </a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/board-of-management">Board of Management</a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/advisory-boards">Advisory Board</a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/university-recognition">University Recognition &amp; Governance</a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/awards-and-accolades">Awards &amp; Accolades </a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/sustainability">Sustainability</a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/business-incubation-and-startups">Business Incubation &amp; Start-ups</a></div>
# <div class="menu_heading"><a class="colorblack" href="/about-nu/directions-and-maps">Direction &amp; Maps</a></div>
# <div class="menu_main_heading">NU Portal</div>
# <div class="menu_heading"><a class="colorblack" href="/staff">Staff</a></div>
# <div class="menu_heading"><a class="colorblack" href="/parents">Parents</a></div>
# <div class="menu_heading"><a class="colorblack" href="/alumni">Alumni</a></div>
# <div class="menu_heading"><a class="colorblack" href="/students">Students</a></div>
# </div>
# </div>
# <div class="col-sm-4">
# <div class="center_menu">
# <div class="menu_main_heading"><a class="color83181a" href="/campus">Campus Life</a></div>
# <div class="menu_heading"><a class="colorblack" href="/campus/facilities">Facilities</a></div>
# <div class="menu_heading"><a class="colorblack" href="/campus/clubs">Clubs</a></div>
# <div class="menu_heading"><a class="colorblack" href="/campus/events">Events</a></div>
# <div class="menu_heading"><a class="colorblack" href="/campus-buzz">Campus Buzz</a></div>
# <div class="menu_heading"><a class="colorblack" href="/campus/the-asian-lenses-forum">The Asian Lenses Forum</a></div>
# <div class="menu_heading"><a class="colorblack" href="/campus/community-connect">Community Connect </a></div>
# <div class="menu_main_heading"><a class="color83181a" href="/partnerships">Partnership</a></div>
# <div class="menu_heading"><a class="colorblack" href="/partnerships/academic">Academic</a> </div>
# <div class="menu_heading"><a class="colorblack" href="/partnerships/industry">Industry</a> </div>
# <div class="menu_heading"><a class="colorblack" href="/partnerships/research">Research </a></div>
# <div class="menu_main_heading"><a class="color83181a" href="/research">Research</a></div>
# <div class="menu_heading"><a class="colorblack" href="/research/cse-doctoral-symposium">CSE Doctoral Symposium</a> </div>
# <div class="menu_heading"><a class="colorblack" href="/research/research-areas">Research Areas</a> </div>
# <div class="menu_heading"><a class="colorblack" href="/research/labs-and-centres-of-excellence">Labs and Centres of Excellence </a></div>
# <div class="menu_heading"><a class="colorblack" href="/research/teaching-learning-and-technology">Teaching-Learning Process &amp; Technology </a></div>
# <div class="menu_heading"><a class="colorblack" href="/research/undergraduate-research">Undergraduate Research</a></div>
# <div class="menu_heading"><a class="colorblack" href="/research/nu-innovators-challenge">The NU Innovators Challenge 2018</a>
# </div>
# </div>
# </div>
# <div class="col-sm-4">
# <div class="center_menu2">
# <div class="menu_main_heading"><a class="color83181a" href="/faculty">Faculty </a></div>
# <div class="menu_main_heading"><a class="color83181a" href="/campus-buzz">Events &amp; Updates </a></div>
# <div class="menu_main_heading"><a class="color83181a" href="/take-a-virtual-tour-of-nu-campus">Video Tour </a></div>
# <div class="menu_main_heading"><a class="color83181a" href="/testimonials">Testimonial</a> </div>
# <div class="menu_main_heading"><a class="color83181a" href="/faqs">FAQ </a></div>
# <div class="menu_main_heading"><a class="color83181a" href="/careers">Careers </a></div>
# <div class="menu_main_heading"><a class="color83181a" href="/contact-us">Contact Us </a></div>
# </div>
# </div>
# </div>
# <div class="phonemenu" id="style-3">
# <div class="col-sm-12">
# <ul>
# <li><a class="color83181a" href="/about-nu">About NU</a></li>
# <div class="phonemenu_inner">
# <a class="colorblack" href="/about-nu/vision-and-mission">Vision &amp; Mission<br/>
# </a>
# <a class="colorblack" href="/about-nu/core-principles">Core Principles<br/>
# </a>
# <a class="colorblack" href="/about-nu/leadership">Leadership<br/>
# </a>
# <a class="colorblack" href="/about-nu/board-of-management">Board of Management<br/>
# </a>
# <a class="colorblack" href="/about-nu/advisory-boards">Advisory Board<br/>
# </a>
# <a class="colorblack" href="/about-nu/university-recognition">University Recognition<br/>
# </a>
# <a class="colorblack" href="/about-nu/awards-and-accolades">Awards &amp; Accolades<br/>
# </a>
# <a class="colorblack" href="/about-nu/sustainability">Sustainability<br/>
# </a>
# <a class="colorblack" href="/about-nu/business-incubation-and-startups">Business Incubation &amp; Start-ups<br/>
# </a>
# <a class="colorblack" href="/about-nu/directions-and-maps">Direction &amp; Maps<br/>
# </a>
# </div>
# <li><a class="color83181a" href="/faculty">FACULTY</a></li>
# <li><a class="color83181a" href="">RESEARCH</a></li>
# <div class="phonemenu_inner">
# <a class="colorblack" href="">CSE Doctoral Symposium<br/>
# </a>
# <a class="colorblack" href="">Research Areas<br/>
# </a>
# <a class="colorblack" href="">Labs and Centres of Excellence<br/>
# </a>
# <a class="colorblack" href="">Teaching-Learning Process &amp; Technology<br/>
# </a>
# <a class="colorblack" href="/research/undergraduate-research">Undergraduate Research<br/>
# </a>
# <a class="colorblack" href="/research/nu-innovators-challenge">The NU Innovators Challenge 2018<br/>
# </a>
# </div>
# <li><a class="color83181a" href="/campus">CAMPUS LIFE</a></li>
# <div class="phonemenu_inner">
# <a class="colorblack" href="/campus/facilities">Facilities<br/>
# </a>
# <a class="colorblack" href="/campus/clubs">Clubs<br/>
# </a>
# <a class="colorblack" href="/campus/events">Events<br/>
# </a>
# <a class="colorblack" href="/campus-buzz">Campus Buzz<br/>
# </a>
# <a class="colorblack" href="/campus/the-Asian-lenses-forum">The Asian Lenses Forum<br/>
# </a>
# <a class="colorblack" href="/campus/community-connect">Community Connect<br/>
# </a>
# </div>
# <li><a class="color83181a" href="/partnerships">PARTNERSHIP</a></li>
# <div class="phonemenu_inner">
# <a class="colorblack" href="/partnerships/academic">Academic<br/>
# </a>
# <a class="colorblack" href="/partnerships/industry">Industry<br/>
# </a>
# <a class="colorblack" href="/partnerships/research">Research<br/>
# </a>
# </div>
# <li><a class="color83181a" href="/campus/events">EVENTS &amp; UPDATES</a></li>
# <li><a class="color83181a" href="/video-tour">VIDEO TOUR</a></li>
# <li><a class="color83181a" href="">NU PORTAL</a></li>
# <div class="phonemenu_inner">
# <a class="colorblack" href="/staff">Staff<br/>
# </a>
# <a class="colorblack" href="/parents">Parents<br/>
# </a>
# <a class="colorblack" href="/alumni">Alumni<br/>
# </a>
# <a class="colorblack" href="/students">Students<br/>
# </a>
# </div>
# <li><a class="color83181a" href="/testimonials">TESTIMONIAL</a></li>
# <li><a class="color83181a" href="/faqs">FAQ</a></li>
# <li><a class="color83181a" href="/careers">CAREERS</a></li>
# <li><a class="color83181a" href="/contact-us">CONTACT US</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mobile_nvabar_extra" id="mobile_nvabar_extra">
# <div class="container">
# <div class="future_students commoncl" id="future_students">
# <strong>FUTURE STUDENTS</strong>
# </div>
# <div class="placement_menu commoncl" id="placement_menu">
# <a class="colorwhite" href="/placements" style="text-decoration: none; color: white;"><b>PLACEMENTS</b></a>
# </div>
# <a class="colorwhite" href="">
# <div class="why_nu_menu commoncl" id="why_nu_menu">
# <a class="colorwhite" href="/why-nu" style="text-decoration: none; color: white;"><b>WHY NU</b></a>
# </div>
# </a>
# </div>
# </div>
# <div class="mynavbar1" id="navbar1" style="height:  500px;overflow:  scroll;overflow-x:hidden;display:none;">
# <div class="triangle_menubar_mobile"></div>
# <div class="panel-group" id="accordion1" role="tab">
# <h4 class="panel-title accor">
# <a aria-expanded="true" class="accordion-toggle" data-parent="#accordion1" data-toggle="collapse" href="">
# <span class="menu2_heading">FOR CLASS XII STUDENTS</span>
# </a>
# </h4>
# <div aria-expanded="true" class="panel-collapse collapse in" id="collapseOne" style="">
# <div class="panel-body" id="accordion2">
# <ul style="margin-left: 23px;font-size:medium;">
# <div aria-multiselectable="true" class="panel-group" id="accordion">
# <li><a aria-controls="collapseOne1" aria-expanded="false" class="collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapseOne1" role="button">BTech Computer Science &amp; Engineering (CSE)
#
#                                 </a></li>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapseOne1" style="">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/b-tech/computer-science-and-engineering">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/b-tech/computer-science-and-engineering">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/b-tech/computer-science-and-engineering">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion" data-toggle="collapse" href="#collapseTwo2">BTech Electronics &amp; Communication Engineering (ECE)
#                                     </a>
# </li>
# <div class="panel-collapse collapse" id="collapseTwo2">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/b-tech/electronics-and-communication-engineering">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/b-tech/electronics-and-communication-engineering">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/b-tech/electronics-and-communication-engineering">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion" data-toggle="collapse" href="#collapseThree">BTech Biotechnology (BT)
#                                     </a>
# </li>
# <div class="panel-collapse collapse" id="collapseThree">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/b-tech/biotechnology">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/b-tech/biotechnology">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/b-tech/biotechnology">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion" data-toggle="collapse" href="#MBAACCORD">4-Year Integrated MSc Computer Science
#                                     </a>
# </li>
# <div class="panel-collapse collapse" id="MBAACCORD">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/m-sc-cs">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/m-sc">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/m-sc">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion" data-toggle="collapse" href="#DDEGREEACCORD">5-Year Integrated M.Tech
#                                     </a>
# </li>
# <div class="panel-collapse collapse" id="DDEGREEACCORD">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/dual-degree">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/m-tech">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/m-tech">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion" data-toggle="collapse" href="#bbaprogamme">BBA Programme
#                                     </a>
# </li>
# <div class="panel-collapse collapse" id="bbaprogamme">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/bba">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/bba">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/bba/academic-calendar">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion" data-toggle="collapse" href="#DDEGREEACCORD2">4-Year Integrated MBA Programme
#                                     </a>
# </li>
# <div class="panel-collapse collapse" id="DDEGREEACCORD2">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/integrated-bba-mba">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/integrated-bba-mba-programme">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/4-year-integrated-mba/academic-calendar">Academics</a>
# </div>
# </div>
# </div>
# </ul>
# </div>
# </div>
# <h4 class="panel-title accor">
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapseTwo">
# <span class="menu2_heading">FOR PG PROGRAMMES</span>
# </a>
# </h4>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapseTwo">
# <ul style="margin-left: 23px;font-size:medium;">
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#Mteh12">M.Tech GIS
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="Mteh12">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/m-tech/geographic-information-systems">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/m-tech">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/m-tech">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#PHDACCORD">M.Tech ET
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="PHDACCORD">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/m-tech/educational-technology">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/m-tech">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/m-tech">Academics</a>
# </div>
# </div>
# </ul>
# </div>
# <h4 class="panel-title accor">
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapse3">
# <span class="menu2_heading">INDUSTRY SPONSORED</span>
# </a>
# </h4>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapse3">
# <ul style="margin-left: 23px;font-size:medium;">
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapse31">MBA (Business Analytics) with WNS
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapse31">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/industry-sponsored/mba-business-analytics-with-wns">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/industry-sponsored/mba-business-analytics">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/industry-sponsored/mba-business-analytics-with-wns">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapse32">MBA (Intelligent Data Sciences) with NIIT Technologies
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapse32">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/industry-sponsored/mba-intelligent-data-science-with-niit-technologies">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/industry-sponsored/mba-intelligent-data-science">Admissions</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapse33">MBA (Finance &amp; Banking) with ICICI Bank
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapse33">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/industry-sponsored/mba-finance-and-banking-with-icici-bank">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/industry-sponsored/mba-icici">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/industry-sponsored/pgd-banking-and-finance-with-united-bank-of-india">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapse34">M.Tech (Cyber Security) with PwC
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapse34">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/industry-sponsored/m-tech-cyber-security-with-pwc">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/industry-sponsored/m-tech-cyber-security">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/industry-sponsored/m-tech-cyber-security-with-pwc">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapse35">PGDBRM with Federal Bank
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapse35">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/industry-sponsored/pgdbrm-with-federal-bank">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/industry-sponsored/pgdbrm-federal-bank">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/industry-sponsored/pgdbrm-with-federal-bank">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapse36">PGD (Banking &amp; Finance) with United Bank of India
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapse36">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/industry-sponsored/pgd-banking-and-finance-with-united-bank-of-india">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/industry-sponsored/pgd-with-united-bank-of-india">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/industry-sponsored/pgd-banking-and-finance-with-united-bank-of-india">Academics</a>
# </div>
# </div>
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapse37">PGD (Banking &amp; Finance) with Bank of Maharashtra
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapse37">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/programmes/industry-sponsored/pgd-banking-and-finance-with-with-bank-of-maharashtra">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/admissions/industry-sponsored/pgd-banking-and-finance-with-with-bank-of-maharashtra  ">Admissions</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/industry-sponsored/pgd-banking-and-finance-with-with-bank-of-maharashtra">Academics</a>
# </div>
# </div>
# </ul>
# </div>
# <h4 class="panel-title accor">
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapseFour">
# <span class="menu2_heading"> DOCTORAL PROGRAMMES</span>
# </a>
# </h4>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapseFour">
# <ul style="margin-left: 23px;font-size:medium;">
# <li>
# <a aria-expanded="false" class="accordion-toggle collapsed" data-parent="#accordion1" data-toggle="collapse" href="#collapse41">PhD programmes
#                             </a>
# </li>
# <div aria-expanded="false" class="panel-collapse collapse" id="collapse41">
# <div class="panel-body" style="font-size:medium;">
# <a class="new_color_browm_bold" href="/academics/phd">Programme Details</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/phd/academic-calender">Academic calender</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/phd/academic-structure">Academic Structure</a>
# <br/>
# <a class="new_color_browm_bold" href="/academics/phd/doctoral-students">Doctoral Students</a>
# </div>
# </div>
# </ul>
# </div>
# </div>
# <div class="width100Per">
# <div class="master">
# <div class="beradCrumbs"><ul><li><a href="/index">Home</a></li><li>Faculty </li></ul></div>
# </div>
# <form action="./faculty" id="ctl00" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/wEPDwULLTE4MTczNTA0NzJkZGWWBzZvMKG3lJZz07zUx4i1EAWVNEDdrMHeini3v9NZ"/>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="18A240E6"/>
# <div class="bannerSection"><div class="master"><div class="bannerContentSection white">The People who make it happen</div></div></div>
# <div class="master-sub">
# <div class="row middleHolder">
# <div class="row middleHolder facultyPage" style="margin-left: 5px;">
# <!--<div class="colLeft">
#                     <div class="leftAcc">
#                         <ul class="sub-child" style="display:none">
#       <li class="has-subchild root"><a class="accTextActive" href="/faculty">Faculty</a><span></span>
#         <ul class="sub-menu" style="display:block;">
#         <li><a href="/faculty/founding-professors">Founding Professors</a></li>
#                                     <li><a class="active" href="/faculty/regular-faculty">Faculty at NU</a></li>
#
#           <li><a href="/faculty/staff">Staff</a></li>
#           <li><a href="/faculty/careers-apply-online">Apply Now</a></li>
#                                 </ul>
#                             </li>
#                         </ul>
#                     </div>
#
#
#
#                 </div>-->
# <div class="colfullWid" id="dvDefault">
# <h1>People</h1>
# <div class="facultyFilterSec">
# <div class="facultyFilterDiv">
# <div class="filterByDepart">
# <span>Filter by</span>
# <div class="slct-filter">
# <select class="selectBoxCustom2" id="ddlSubject_Details" onchange="fnBindFaculty();">
# <option value="">All</option>
# <option value="16">Biotechnology &amp; Bionformatics</option><option value="13">Computer Science &amp; Engineering</option><option value="19">Educational Technology</option><option value="17">Electronics &amp; Communications Engineering</option><option value="14">Humanities &amp; Social Sciences</option><option value="12">Management</option><option value="18">Mathematics &amp; Basic Sciences</option><option value="15">University Advisory</option>
# </select>
# </div>
# <div class="filterByPro">
# <select class="selectBoxCustom2" id="ddlfaucltyType" onchange="fnBindFaculty();">
# <option value="">All</option>
# <option value="7">Founding Professors</option><option value="5">University Faculty</option><option value="8">Visiting Faculty</option><option value="6">Industry Faculty</option>
# </select>
# </div>
# </div>
# </div>
# </div>
# <div class="facultyMainWrap" id="dvfacultyDetails7"><h2 class="formheading bold">Founding Professors</h2><ul><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/arun-nigavekar"><img src="/resourcecontent/arun-nigavekar_4701.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/arun-nigavekar">Dr. Arun Nigavekar</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/ashok-misra"><img src="/resourcecontent/ashok-mishra_4273.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/ashok-misra">Prof. Ashok Misra</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/dinesh-singh"><img src="/resourcecontent/dinesh-singh_9510.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/dinesh-singh">Prof. Dinesh Singh</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/ganesh-natarajan"><img src="/resourcecontent/ganesh_natarajan_9643.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/ganesh-natarajan">Dr. Ganesh Natarajan</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/karmeshu"><img src="/resourcecontent/karmeshu_9049.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/karmeshu">Prof. Karmeshu</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/krishnaswamy-kasturirangan"><img src="/resourcecontent/kkasthurirangan_5137.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/krishnaswamy-kasturirangan">Dr. Krishnaswamy Kasturirangan</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/marmar-mukhopadhyay"><img src="/resourcecontent/marmar-mukhopadhyay_6510.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/marmar-mukhopadhyay">Prof. Marmar Mukhopadhyay</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/r-a-mashelkar"><img src="/resourcecontent/r-a-mashelkar_8084.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/r-a-mashelkar">Dr. R.A. Mashelkar</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/rajeev-sangal"><img src="/resourcecontent/rajeev-sangal_6479.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/rajeev-sangal">Prof. Rajeev Sangal</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/sugata-mitra"><img src="/resourcecontent/sugata-mitra_7739.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/sugata-mitra">Prof. Sugata Mitra</a></h3></div></div></li><li data-faucltytype="7" data-subject="15"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/v-rajaraman"><img src="/resourcecontent/raja-raman_1034.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/v-rajaraman">Prof. V. Rajaraman</a></h3></div></div></li><li data-faucltytype="7" data-subject="19"><div class="profileDetails"><div class="profileImageSec"><a href="/faculty/vijay-vasantrao-mandke"><img src="/resourcecontent/vijay-mandke_927.jpg"/></a></div><div class="profileDescription"><h3><a href="/faculty/vijay-vasantrao-mandke">Prof. Vijay Vasantrao Mandke</a></h3></div></div></li></ul></div><div class="facultyMainWrap" id="dvfacultyDetails5"><h2 class="formheading bold">University Faculty</h2><ul><li data ...
# </div>
# </div>
# </div>
# </div>
# </form>
# <div class="clearfix">
# </div>
# <section class="section7">
# <div class="container mobpaddingtop">
# <div class="row">
# <div class="col-md-3 col-xs-6">
# <a href="https://nucleus.niituniversity.in/ug-prog/Welcome.aspx" target="_blank">Admissions 2018</a>
# <br/>
# <a href="/programmes">Programme Details</a>
# <br/>
# <a href="/About-NU">About NU</a>
# <br/>
# <a href="/Why-NU">Why NU</a>
# </div>
# <div class="col-md-3 col-xs-6">
# <a href="/placements">Placements</a>
# <br/>
# <a href="/campus-buzz">Campus Buzz</a>
# <br/>
# <a href="/research">Research</a>
# <br/>
# <a href="/nu-in-the-media">NU in the Media</a>
# </div>
# <div class="col-md-3 col-xs-6">
# <a href="/contact-us">Contact Us</a>
# <br/>
# <a href="/press-release">Press Release</a>
# <br/>
# <a href="/newsletter">Newsletter</a>
# <br/>
# <a href="/faqs">FAQs</a>
# </div>
# <div class="col-md-3 col-xs-6">
#                     Follow us on :
#
#                     <div class="">
# <a href="https://www.facebook.com/NIITUniv" target="_blank">
# <img class="padright10" src="/mobile_images/facebook.png"/></a>
# <a href="https://twitter.com/niituniversity" target="_blank">
# <img class="padright10" src="/mobile_images/twitter.png"/></a>
# <a href="https://www.instagram.com/niituniv/" target="_blank">
# <img class="padright10" src="/mobile_images/instagram.png"/></a>
# <a href="https://www.youtube.com/user/niituniv" target="_blank">
# <img class="padright10" src="/mobile_images/youtube.png"/></a>
# <a href="http://nuxpress.niituniversity.in/" target="_blank">
# ...
#     "facultyName": "Suman Sanyal",
#     "facultyDegree": "",
#     "facultyUrl": "/suman-sanyal"
#   },
#   {
#     "facultyId": "251",
#     "facultyTypeId": "5",
#     "facultySubjectId": "16",
#     "facultyImage": "sunil-khanna_9728.jpg",
#     "facultySalutation": "Prof.",
#     "facultyName": "Sunil Khanna",
#     "facultyDegree": "",
#     "facultyUrl": "/sunil-khanna"
#   },
#   {
#     "facultyId": "253",
#     "facultyTypeId": "5",
#     "facultySubjectId": "12",
#     "facultyImage": "sushil-kalyani_147.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Sushil Kalyani",
#     "facultyDegree": "",
#     "facultyUrl": "/sushil-kalyani"
#   },
#   {
#     "facultyId": "244",
#     "facultyTypeId": "5",
#     "facultySubjectId": "12",
#     "facultyImage": "shivendra-mathur_9831.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Shivendra Mathur",
#     "facultyDegree": "",
#     "facultyUrl": "/shivendra-mathur"
#   },
#   {
#     "facultyId": "235",
#     "facultyTypeId": "5",
#     "facultySubjectId": "12",
#     "facultyImage": "raj-kovid_4229.png",
#     "facultySalutation": "Dr.",
#     "facultyName": "Raj Kumar Kovid",
#     "facultyDegree": "",
#     "facultyUrl": "/raj-kumar-kovid"
#   },
#   {
#     "facultyId": "230",
#     "facultyTypeId": "5",
#     "facultySubjectId": "12",
#     "facultyImage": "pranav-ranjan_6105.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Pranav Ranjan",
#     "facultyDegree": "",
#     "facultyUrl": "/pranav-ranjan"
#   },
#   {
#     "facultyId": "233",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "prosenjit-gupta_126.jpg",
#     "facultySalutation": "Prof.",
#     "facultyName": "Prosenjit Gupta",
#     "facultyDegree": "",
#     "facultyUrl": "/prosenjit-gupta"
#   },
#   {
#     "facultyId": "225",
#     "facultyTypeId": "5",
#     "facultySubjectId": "14",
#     "facultyImage": "parimal-mandke_2357.jpg",
#     "facultySalutation": "Prof.",
#     "facultyName": "Parimal V Mandke",
#     "facultyDegree": "",
#     "facultyUrl": "/parimal-v-mandke"
#   },
#   {
#     "facultyId": "221",
#     "facultyTypeId": "5",
#     "facultySubjectId": "12",
#     "facultyImage": "neeti-mathur_3936.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Neethi Mathur",
#     "facultyDegree": "",
#     "facultyUrl": "/neethi-mathur"
#   },
#   {
#     "facultyId": "222",
#     "facultyTypeId": "5",
#     "facultySubjectId": "17",
#     "facultyImage": "neha-tiwari_1605.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Neha Tiwari",
#     "facultyDegree": "",
#     "facultyUrl": "/neha-tiwari"
#   },
#   {
#     "facultyId": "215",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "manoj-kumar_377.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Manoj Kumar",
#     "facultyDegree": "",
#     "facultyUrl": "/manoj-kumar"
#   },
#   {
#     "facultyId": "2307",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "ayan-nandy_8104.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Ayan Nandy",
#     "facultyDegree": "PhD in Computer Science",
#     "facultyUrl": "/ayan-nandy"
#   },
#   {
#     "facultyId": "203",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "gaurav-varshney_3550.png",
#     "facultySalutation": "Mr.",
#     "facultyName": "Gaurav Varshney",
#     "facultyDegree": "",
#     "facultyUrl": "/gaurav-varshney"
#   },
#   {
#     "facultyId": "217",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "meera_8505.jpg",
#     "facultySalutation": "Ms.",
#     "facultyName": "Meera S Datta",
#     "facultyDegree": "",
#     "facultyUrl": "/meera-s-datta"
#   },
#   {
#     "facultyId": "218",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "narayan_6540.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Narayan Kumar",
#     "facultyDegree": "",
#     "facultyUrl": "/narayan-kumar"
#   },
#   {
#     "facultyId": "275",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "ashoo-dubey_5457.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Ashoo Dubey",
#     "facultyDegree": "Masters in Information Technology",
#     "facultyUrl": "/ashoo-dubey"
#   },
#   {
#     "facultyId": "219",
#     "facultyTypeId": "5",
#     "facultySubjectId": "17",
#     "facultyImage": "navin-kumar-kapur_605.jpg",
#     "facultySalutation": "Prof.",
#     "facultyName": "Navin Kapur",
#     "facultyDegree": "",
#     "facultyUrl": "/navin-kapur"
#   },
#   {
#     "facultyId": "186",
#     "facultyTypeId": "5",
#     "facultySubjectId": "12",
#     "facultyImage": "arun-kumar_4147.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Arun Kumar",
#     "facultyDegree": "",
#     "facultyUrl": "/arun-kumar"
#   },
#   {
#     "facultyId": "192",
#     "facultyTypeId": "5",
#     "facultySubjectId": "12",
#     "facultyImage": "deepak-khanna_6037.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Deepak Khanna",
#     "facultyDegree": "",
#     "facultyUrl": "/deepak-khanna"
#   },
#   {
#     "facultyId": "197",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "gaurav-sharma_3496.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Gaurav Sharma",
#     "facultyDegree": "",
#     "facultyUrl": "/gaurav-sharma"
#   },
#   {
#     "facultyId": "198",
#     "facultyTypeId": "5",
#     "facultySubjectId": "14",
#     "facultyImage": "gurendra-nath-bhardwaj_6933.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Gurendra Nath Bhardwaj",
#     "facultyDegree": "",
#     "facultyUrl": "/gurendra-nath-bhardwaj"
#   },
#   {
#     "facultyId": "268",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "akhlesh_9498.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Akhlesh Agarwal",
#     "facultyDegree": "",
#     "facultyUrl": "/akhlesh-agarwal"
#   },
#   {
#     "facultyId": "208",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "kumar-nitesh_9062.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Kumar Nitesh",
#     "facultyDegree": "",
#     "facultyUrl": "/kumar-nitesh"
#   },
#   {
#     "facultyId": "212",
#     "facultyTypeId": "5",
#     "facultySubjectId": "18",
#     "facultyImage": "ganapathirao_2940.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "M.Ganapathirao",
#     "facultyDegree": "",
#     "facultyUrl": "/m-ganapathirao"
#   },
#   {
#     "facultyId": "213",
#     "facultyTypeId": "5",
#     "facultySubjectId": "16",
#     "facultyImage": "mandeep-dadhwal_9357.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Mandeep Dadhwal",
#     "facultyDegree": "",
#     "facultyUrl": "/mandeep-dadhwal"
#   },
#   {
#     "facultyId": "265",
#     "facultyTypeId": "5",
#     "facultySubjectId": "17",
#     "facultyImage": "vikas-upadhyaya_4335.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Vikas Upadhyaya",
#     "facultyDegree": "",
#     "facultyUrl": "/vikas-upadhyaya"
#   },
#   {
#     "facultyId": "1285",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "shweta malwe_4737.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Shweta R. Malwe",
#     "facultyDegree": "M.Tech and Ph.D",
#     "facultyUrl": "/shweta-r-malwe"
#   },
#   {
#     "facultyId": "2285",
#     "facultyTypeId": "5",
#     "facultySubjectId": "18",
#     "facultyImage": "dr-vinay-sharma_4904.jpg",
#     "facultySalutation": "Dr",
#     "facultyName": "Vinay Sharma",
#     "facultyDegree": "Ph.D, M.Sc, B.Sc",
#     "facultyUrl": "/vinay-sharma"
#   },
#   {
#     "facultyId": "2289",
#     "facultyTypeId": "5",
#     "facultySubjectId": "18",
#     "facultyImage": "dr-tapan-naskar_8653.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Tapan Naskar",
#     "facultyDegree": "PhD",
#     "facultyUrl": "/dr-tapan-naskar"
#   },
#   {
#     "facultyId": "2291",
#     "facultyTypeId": "5",
#     "facultySubjectId": "17",
#     "facultyImage": "faculty_arghya_7471.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Arghya Guchhait",
#     "facultyDegree": "Ph.D",
#     "facultyUrl": "/arghya-guchhait"
#   },
#   {
#     "facultyId": "2292",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "vikas-malviya_5912.png",
#     "facultySalutation": "Mr.",
#     "facultyName": "Vikas Malviya",
#     "facultyDegree": "Ph.D",
#     "facultyUrl": "/vikas-malviya"
#   },
#   {
#     "facultyId": "2293",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "nidhi-chahal_4581.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Nidhi Chahal",
#     "facultyDegree": "Ph.D",
#     "facultyUrl": "/nidhi-chahal"
#   },
#   {
#     "facultyId": "2296",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "prashant-srivastava_6218.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Prashant Srivastava",
#     "facultyDegree": "Ph.D. (Computer Science)",
#     "facultyUrl": "/prashant-srivastava"
#   },
#   {
#     "facultyId": "2312",
#     "facultyTypeId": "5",
#     "facultySubjectId": "16",
#     "facultyImage": "soumya-chakraborty_9323.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Soumyadeep Chakraborty",
#     "facultyDegree": "B.Tech",
#     "facultyUrl": "/soumya-chakraborty"
#   },
#   {
#     "facultyId": "280",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "arijit-karati-24_5745.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Arijit Karati",
#     "facultyDegree": "Ph.D",
#     "facultyUrl": "/arijit-karati"
#   },
#   {
#     "facultyId": "266",
#     "facultyTypeId": "5",
#     "facultySubjectId": "12",
#     "facultyImage": "vivek-saxena_8972.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Vivek Saxena",
#     "facultyDegree": "",
#     "facultyUrl": "/vivek-saxena"
#   },
#   {
#     "facultyId": "2299",
#     "facultyTypeId": "5",
#     "facultySubjectId": "17",
#     "facultyImage": "ipseeta-nanda_7989.jpg",
#     "facultySalutation": "Ms.",
#     "facultyName": "Ipseeta Nanda",
#     "facultyDegree": "M.Tech., Ph.D. (Pursuing)",
#     "facultyUrl": "/ipseeta-nanda"
#   },
#   {
#     "facultyId": "195",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "g-krishna_3687.jpg",
#     "facultySalutation": "Prof.",
#     "facultyName": "G Krishnamurthy",
#     "facultyDegree": "",
#     "facultyUrl": "/g-krishnamurthy"
#   },
#   {
#     "facultyId": "267",
#     "facultyTypeId": "5",
#     "facultySubjectId": "18",
#     "facultyImage": "vivek-srivastava_4018.png",
#     "facultySalutation": "Dr.",
#     "facultyName": "Vivek Srivastava",
#     "facultyDegree": "",
#     "facultyUrl": "/vivek-srivastava"
#   },
#   {
#     "facultyId": "176",
#     "facultyTypeId": "5",
#     "facultySubjectId": "12",
#     "facultyImage": "abhisek-dutta_8715.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Abhisek Dutta",
#     "facultyDegree": "",
#     "facultyUrl": "/abhisek-dutta"
#   },
#   {
#     "facultyId": "178",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "deepika-prakash_2485.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Deepika Prakash",
#     "facultyDegree": "M.Tech, Ph.D",
#     "facultyUrl": "/deepika-prakash"
#   },
#   {
#     "facultyId": "179",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "amit-kumar_683.jpg",
#     "facultySalutation": "Mr.",
#     "facultyName": "Amit Kumar",
#     "facultyDegree": "",
#     "facultyUrl": "/amit-kumar"
#   },
#   {
#     "facultyId": "182",
#     "facultyTypeId": "5",
#     "facultySubjectId": "14",
#     "facultyImage": "anshima-p-shrivastav_9829.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Anshima P Srivastava",
#     "facultyDegree": "",
#     "facultyUrl": "/anshima-p-srivastava"
#   },
#   {
#     "facultyId": "183",
#     "facultyTypeId": "5",
#     "facultySubjectId": "13",
#     "facultyImage": "anul-haq_3180.jpg",
#     "facultySalutation": "Dr.",
#     "facultyName": "Anul Haq",
#     "facultyDegree": "",
#     "facultyUrl": "/anul-haq"
#   }
# ];
#         var objDefaultData="";
#
#         //$(document).ready(function(){
#             objDefaultData=$("#dvDefault").html();
#         // });
#
#         function fnBindFaculty() {
#             if ($("#ddlfaucltyType").val() == "" && $("#ddlSubject_Details").val()==""){
#                 $("#dvDefault").html(objDefaultData);
#                 return;
#             }
#
#             var whereClause;
#             if ($("#ddlSubject_Details").val() == ""){
#                 whereClause = "";
#                 //alert(1);
#             }
#             if ($("#ddlfaucltyType").val() == "" && $("#ddlSubject_Details").val() != ""){
#                 //alert(2);
#                 whereClause = " && facultySubjectId=='" + $("#ddlSubject_Details").val().trim() + "' ";
#             }
#             if ($("#ddlfaucltyType").val() != "" && $("#ddlSubject_Details").val() == ""){
#                 whereClause = " && facultyTypeId=='" + $("#ddlfaucltyType").val().trim() + "' ";
#                 //alert(3);
#             }
#             if ($("#ddlfaucltyType").val() != "" && $("#ddlSubject_Details").val() != ""){
#                 whereClause = " && facultySubjectId=='" + $("#ddlSubject_Details").val().trim() + "' && facultyTypeId == '" + $("#ddlfaucltyType").val().trim() + "' ";
#                 //  alert(4);
#             }
#             var strSql = "select * from objFacultyJson where ( 1==1 ";
#             strSql += whereClause;
#             strSql += " )";
#             //alert(strSql);
#             var objJson = jsonsql.query(strSql, objFacultyJson);
#            // console.log(objJson);
#             objJson = _.sortBy(objJson, "facultyName");
#            // console.log(objJson);
#             var facultyListingData = "";
#             //alert(objJson);
#             if(objJson.length>0){
#                 facultyListingData += "<ul>";
#                 for (i = 0; i < objJson.length; i++) {
#                     facultyListingData += "<li data-faucltyType=" + objJson[i].facultyTypeId + "  data-subject=" + objJson[i].facultySubjectId + " >";
#                     facultyListingData += "<div class='profileDetails'>";
#                     facultyListingData += "<div class='profileImageSec'><a href='/faculty" + objJson[i].facultyUrl + "'><img src='/resourcecontent/" + objJson[i].facultyImage + "'></a></div>";
#                     facultyListingData += "<div class='profileDescription'>";
#                     facultyListingData += "<h3><a href='/faculty" + objJson[i].facultyUrl + "'>"+objJson[i].facultySalutation +" " +objJson[i].facultyName + "</a></h3>";
#                     facultyListingData += "</div>";
#                     facultyListingData += "</div>";
#                     facultyListingData += "</li>";
#                 }
#                 facultyListingData += "</ul>";
#             }
#             //alert(facultyListingData);
#             if(facultyListingData=="")
#                 facultyListingData="<h1>No Result Found...</h1>";
#             $("#dvfacultyDetails7").html(facultyListingData);
#             $("#dvfacultyDetails8").remove();
#             $("#dvfacultyDetails6").remove();
#             $("#dvfacultyDetails5").remove();
#         }
#
#     </script>
# <script>
#         $(function () {
#             $("#slct1").selectbox();
#             $("#slct2").selectbox();
#         });
#
#         //function fnVideoFilter() {
#         //    var selectSubject = $("#ddlSubject_Details").val();
#         //    var selectFaculty = $("#ddlfaucltyType").val();
#         //    $(".facultyMainWrap li").each(function () {
#         //        var faucltytype = $(this).data("faucltytype");
#         //        var subject = $(this).data("subject");
#         //        if (selectSubject == "" || selectFaculty == "") {
#         //            $(this).show();
#         //        }
#         //        else if (selectSubject == subject || selectFaculty == faucltytype)
#         //            $(this).show();
#         //        else
#         //            $(this).hide();
#         //    });
#
#         // //   alert(selectSubject);
#         //}
#     </script>
# <script src="/js/underscore-min.js"></script>
# <!--LeadSquared Tracking Code Start-->
# <script src="https://web.mxradon.com/t/Tracker.js" type="text/javascript"></script>
# <script type="text/javascript">
#             pidTracker('4902');
#         </script>
# <!--LeadSquared Tracking Code End-->
# </div></section></header></div></body>
# </html>
